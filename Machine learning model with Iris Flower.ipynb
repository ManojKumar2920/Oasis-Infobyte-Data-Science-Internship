# %% [markdown]
# ![Oasis%20Infobyte.jpg](attachment:Oasis%20Infobyte.jpg)

# %% [markdown]
# # _Oasis Infobyte Internship_
#
# ### _Task 3 - Iris Flower Classification Machine learning model_
#
# _Code Author - Manoj Kumar_
#
# _Data Science Virtual Internship program_

# %% [markdown]
# ## _Import Required Modules_

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")
# %matplotlib inline

# %% [markdown]
# ## _Load the Datasets_

# %%
data = pd.read_csv("E:\Mano@workspace\Datasets\iris.data")
data.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
columns=["Sepal Length","Sepal Width","Petal Length","Petal Width","SpeciesTypes"]
data=pd.read_csv("E:\Mano@workspace\Datasets\iris.data",names=columns)

# %%
data.shape
# Out:
# (150, 5)

# %%
data.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width SpeciesTypes
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## _Analyze & visualize dataset_

# %%
data.describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data["SpeciesTypes"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: SpeciesTypes, dtype: int64

# %% [markdown]
# ## _Visualize using Seaborn Countplot_

# %%
sns.countplot(x="SpeciesTypes",data=data)
# Out:
# <AxesSubplot: xlabel='SpeciesTypes', ylabel='count'>

# %% [markdown]
# ## _Visualize using Seaborn Pairplot_

# %%
sns.set(style="darkgrid")
sns.pairplot(data,hue="SpeciesTypes")

# %% [markdown]
# ## _Visualize the Species Attributes using Barplot_

# %%
Data=data.values
x=Data[:,0:4]
y=Data[:,4]

# %%
y_data=np.array([np.average(x[:,i][y==j].astype('float32'))for i in range(x.shape[1])for j in (np.unique(y))])
y_data_reshaped=y_data.reshape(4,3)
y_data_reshaped=np.swapaxes(y_data_reshaped,0,1)
x_axis=np.arange(len(columns)-1)
width=0.25

# %%
plt.bar(x_axis,y_data_reshaped[0],width,label='Setosa')
plt.bar(x_axis+width,y_data_reshaped[1],width,label='Versicolor')
plt.bar(x_axis+width*2,y_data_reshaped[2],width,label='Virginica')
plt.xticks(x_axis,columns[:4])
plt.xlabel("Flower Features")
plt.ylabel("Value in cm")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# ## _Model Training & Classification_

# %%
x=data.drop("SpeciesTypes",axis=1)
y=data["SpeciesTypes"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
value=KNeighborsClassifier(n_neighbors=1)

# %%
value.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# ## _Model Training_

# %%
X=[]
for i in range(0,4):
    val=float(input())
    X.append(val)
Flower=np.array([X])
Flower
# Out:
# 1.2
# 2.2
# 0.4
# 1.4
# array([[1.2, 2.2, 0.4, 1.4]])

# %%
prediction=value.predict(Flower)
"Prediction of Species Type with given values: {}".format(prediction)
# Out:
# "Prediction of Species Type with given values: ['Iris-setosa']"

# %% [markdown]
# ## _Summary_
#
# _In this Machine learning - Iris Flower classification project , we learned to train our own supervised machine learning model using Iris flower classification with machine learning and we learned the skills of machine learning ,data analysis,data visualiztaion and model creation , etc..._
